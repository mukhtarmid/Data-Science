# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
originalData = pd.read_csv('../../../Data/Obesity prediction.csv')
originalData
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
data = originalData.copy()

# %%
data.sample(10)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 1009    Male  23.000000  1.791867   90.000000            yes  yes  2.067817
# 2094  Female  26.000000  1.643892  111.884535            yes  yes  3.000000
# 1952  Female  19.783234  1.747962  133.936535            yes  yes  3.000000
# 1444  Female  23.652435  1.562724   80.535698            yes  yes  2.000000
# 1510  Female  18.945961  1.605469   82.039000            yes  yes  2.765330
# 1000  Female  25.461411  1.700000   78.055968            yes  yes  2.661556
# 2099  Female  25.974446  1.628855  108.090006            yes  yes  3.000000
# 758     Male  21.000000  1.605404   68.226511             no  yes  2.000000
# 789   Female  37.218161  1.593894   63.320629            yes  yes  2.374640
# 1667    Male  28.404332  1.787379  112.173731            yes  yes  1.878251
#
#          NCP       CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (2111, 17)

# %%
data.isnull().sum()
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    0
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             0
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 24

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %% [markdown]
# ### Data Details:
#
# - Gender: Gender
# - Age: Age
# - Height : in metres
# - Weight : in kgs
# - family_history : Has a family member suffered or suffers from overweight?
# - FAVC : Do you eat high caloric food frequently?
# - FCVC : Do you usually eat vegetables in your meals?
# - NCP : How many main meals do you have daily?
# - CAEC : Do you eat any food between meals?
# - SMOKE : Do you smoke?
# - CH2O : How much water do you drink daily?
# - SCC : Do you monitor the calories you eat daily?
# - FAF: How often do you have physical activity?
# - TUE : How much time do you use technological devices such as cell phone, videogames, television, computer and others?
# - CALC : How often do you drink alcohol?
# - MTRANS : Which transportation do you usually use?
# - Obesity_level (Target Column) : Obesity level

# %%
data['Age'] = data['Age'].apply(lambda x: round(x))

# %%
sns.countplot(data['Gender'])
plt.show()

# %%
sns.lineplot(data['Age'])
plt.show()

# %%
sns.lineplot(data['Height'])
plt.show()

# %%
sns.countplot(pd.cut(data['Weight'], 5).values)
plt.show()

# %%
sns.countplot(data['family_history'])
plt.show()

# %%
sns.countplot(data['FAVC'])
plt.show()

# %%
sns.lineplot(data['FCVC'])
plt.show()

# %%
sns.lineplot(data['NCP'])
plt.show()

# %%
sns.countplot(data['CAEC'])
plt.show()

# %%
sns.countplot(data['SMOKE'])
plt.show()

# %%
sns.lineplot(data['CH2O'])
plt.show()

# %%
sns.countplot(data['SCC'])
plt.show()

# %%
sns.lineplot(data['FAF'])
plt.show()

# %%
sns.lineplot(data['TUE'])
plt.show()

# %%
sns.countplot(data['MTRANS'])
plt.show()

# %%
sns.countplot(data['CALC'])
plt.show()

# %%
sns.countplot(data['Obesity'])
plt.show()

# %%
sns.scatterplot(x=data['Weight'], y=data['Height'], hue=data['Obesity'], size=data['Gender'])
plt.show()

# %%
data[(data['Gender']=='Female') & (data['Obesity']=='Normal_Weight')]
# Out:
#      Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0    Female   21    1.62    64.0            yes   no   2.0  3.0   Sometimes
# 1    Female   21    1.52    56.0            yes   no   3.0  3.0   Sometimes
# 6    Female   23    1.50    55.0            yes  yes   3.0  3.0   Sometimes
# 15   Female   22    1.70    66.0            yes   no   3.0  3.0      Always
# 22   Female   22    1.65    60.0            yes  yes   3.0  3.0   Sometimes
# ..      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 479  Female   17    1.58    50.0             no  yes   1.0  4.0  Frequently
# 480  Female   18    1.57    50.0             no  yes   2.0  3.0   Sometimes
# 482  Female   20    1.58    53.5            yes  yes   2.0  1.0  Frequently
# 489  Female   19    1.56    50.0             no  yes   2.0  1.0   Sometimes
# 494  Female   18    1.67    66.0             no  yes   3.0  3.0   Sometimes
#
# ...
